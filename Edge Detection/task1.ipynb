# %%
import matplotlib.pyplot as plt
from skimage import color, data, feature, img_as_float

image = img_as_float(data.astronaut())

# Convert to grayscale
gray_image = color.rgb2gray(image)

# Apply Canny edge detection
edges = feature.canny(gray_image, sigma=2)

print("Edge Detection using Canny Filter")
print(f"Original image shape: {image.shape}")
print(f"Edges image shape: {edges.shape}")

fig, axes = plt.subplots(1, 3, figsize=(12, 4))
ax = axes.ravel()

ax[0].imshow(image)
ax[0].set_title("Original Image")
ax[0].axis("off")

ax[1].imshow(gray_image, cmap="gray")
ax[1].set_title("Grayscale Image")
ax[1].axis("off")

ax[2].imshow(edges, cmap="gray")
ax[2].set_title("Canny Edges")
ax[2].axis("off")

plt.tight_layout()
plt.show()
# Out:
# Edge Detection using Canny Filter
# Original image shape: (512, 512, 3)
# Edges image shape: (512, 512)
